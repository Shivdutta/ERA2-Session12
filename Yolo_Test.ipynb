# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/Session12/YoloV3-master
# !python detect.py --source /content/drive/MyDrive/Colab_Notebooks/Session12/YoloV3-master/data/TEST --conf-thres 0.1 --output test_out
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Session12/YoloV3-master
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='/content/drive/MyDrive/Colab_Notebooks/Session12/YoloV3-master/data/TEST', output='test_out', img_size=512, conf_thres=0.1, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CPU
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/16 /content/drive/MyDrive/Colab_Notebooks/Session12/YoloV3-master/data/TEST/R_10medium.jpeg: 512x512 6 mushrooms, Done. (2.306s)
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from PIL import Image
from IPython.display import display, HTML

# Define the CSS style to remove scrollbars
remove_scrollbars_css = """
<style>
.output {
    overflow: visible !important;
}
</style>
"""

display(HTML(remove_scrollbars_css))

image_dir = "/content/drive/MyDrive/Colab_Notebooks/Session12/YoloV3-master/test_out"

image_files = os.listdir(image_dir)

image_files = image_files[:16]

fig, axes = plt.subplots(4, 4, figsize=(10, 10))

for i, image_file in enumerate(image_files):
    # Load image
    image_path = os.path.join(image_dir, image_file)
    image = Image.open(image_path)

    # Plot image
    row = i // 4
    col = i % 4
    axes[row, col].imshow(image)
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()
# Out:
# <style>
# .output {
#     overflow: visible !important;
# }
# </style>
